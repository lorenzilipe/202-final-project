# %%
import json
import pandas as pd

# %% [markdown]
# # Loading data

# %%
interactions_file = "data/goodreads_interactions_comics_graphic.json.gz"
interactions = pd.read_json(interactions_file, lines=True, compression="gzip")

interactions.columns
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 2
#       1 interactions_file = "data/goodreads_interactions_comics_graphic.json.gz"
# ----> 2 interactions = pd.read_json(interactions_file, lines=True, compression="gzip")
#       4 interactions.columns
#
# File c:\Users\rynoc\anaconda3\Lib\site-packages\pandas\io\json\_json.py:780, in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options, dtype_backend, engine)
#     777 if convert_axes is None and orient != "table":
#     778     convert_axes = True
# --> 780 json_reader = JsonReader(
#     781     path_or_buf,
#     782     orient=orient,
#     783     typ=typ,
#     784     dtype=dtype,
#     785     convert_axes=convert_axes,
#     786     convert_dates=convert_dates,
#     787     keep_default_dates=keep_default_dates,
#     788     precise_float=precise_float,
#     789     date_unit=date_unit,
#     790     encoding=encoding,
#     791     lines=lines,
#     792     chunksize=chunksize,
#     793     compression=compression,
#     794     nrows=nrows,
#     795     storage_options=storage_options,
#     796     encoding_errors=encoding_errors,
#     797     dtype_backend=dtype_backend,
#     798     engine=engine,
#     799 )
#     801 if chunksize:
#     802     return json_reader
#
# File c:\Users\rynoc\anaconda3\Lib\site-packages\pandas\io\json\_json.py:893, in JsonReader.__init__(self, filepath_or_buffer, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, precise_float, date_unit, encoding, lines, chunksize, compression, nrows, storage_options, encoding_errors, dtype_backend, engine)
#     891     self.data = filepath_or_buffer
#     892 elif self.engine == "ujson":
# --> 893     data = self._get_data_from_filepath(filepath_or_buffer)
#     894     self.data = self._preprocess_data(data)
#
# File c:\Users\rynoc\anaconda3\Lib\site-packages\pandas\io\json\_json.py:949, in JsonReader._get_data_from_filepath(self, filepath_or_buffer)
#     941     filepath_or_buffer = self.handles.handle
#     942 elif (
#     943     isinstance(filepath_or_buffer, str)
#     944     and filepath_or_buffer.lower().endswith(
#    (...)
#     947     and not file_exists(filepath_or_buffer)
#     948 ):
# --> 949     raise FileNotFoundError(f"File {filepath_or_buffer} does not exist")
#     950 else:
#     951     warnings.warn(
#     952         "Passing literal json to 'read_json' is deprecated and "
#     953         "will be removed in a future version. To read from a "
#    (...)
#     956         stacklevel=find_stack_level(),
#     957     )
#
# FileNotFoundError: File data/goodreads_interactions_comics_graphic.json.gz does not exist

# %%
work_id_book_id_dict = pd.read_csv('data/work_id_book_id_dict.csv')
work_id_book_id_dict
# Out:
#         work_id                                            book_id
# 0           797  [3352661, 19545707, 620786, 32620655, 10478927...
# 1          1027                                   [89816, 9172685]
# 2          1315  [863050, 9697547, 412264, 321821, 17790324, 34...
# 3          1398                                             [7552]
# 4          2647  [825059, 437382, 6886316, 13405305, 1023049, 2...
# ...         ...                                                ...
# 62939  58292657                                          [8561995]
# 62940  58346678                                         [13368608]
# 62941  58356540                               [16230999, 19091791]
# 62942  58359101                                         [22016211]
# 62943  58374571                                          [6049120]
#
# [62944 rows x 2 columns]

# %% [markdown]
# # Getting work_ids for each book_id

# %%
import ast
work_id_book_id_dict['book_id'] = work_id_book_id_dict['book_id'].apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else x)
book_id_to_work_id = work_id_book_id_dict.explode('book_id').sort_values('book_id')

book_id_to_work_id
# Out:
#         work_id   book_id
# 13         4676       374
# 62278  57154110       450
# 14         4841       586
# 15         4900       649
# 3825     406956       690
# ...         ...       ...
# 62915  58189202  36478518
# 62917  58190888  36480175
# 30090  19072429  36493971
# 31182  20132139  36494299
# 7900    1085189  36508486
#
# [89411 rows x 2 columns]

# %%
# Verify that there are no duplicate book_id
book_id_to_work_id.groupby('book_id').count().value_counts()
# Out:
# work_id
# 1          89411
# Name: count, dtype: int64

# %% [markdown]
# # Adding work_ids to interactions

# %%
interactions['work_id'] = interactions['book_id'].map(book_id_to_work_id.set_index('book_id')['work_id'])

# %%
interactions.drop(columns=['review_text_incomplete'], inplace=True)

# %%
interactions
# Out:
#                                   user_id   book_id  \
# 0        8842281e1d1347389f2ab93d60773d4d    836610
# 1        8842281e1d1347389f2ab93d60773d4d   7648967
# 2        8842281e1d1347389f2ab93d60773d4d  15704307
# 3        8842281e1d1347389f2ab93d60773d4d   6902644
# 4        8842281e1d1347389f2ab93d60773d4d   9844623
# ...                                   ...       ...
# 7347625  bd3ac2e547a4f521927056cbd6bb5c2f   1484167
# 7347626  bd3ac2e547a4f521927056cbd6bb5c2f    122451
# 7347627  6384a10d5611945b26b25c971f348fa4     85574
# 7347628  e9aea57d21cdf9d91a65687d59518924     15197
# 7347629  762121298ddd3820c9477c6f03f145ab   6493321
#
#                                 review_id  is_read  rating  \
# 0        6b4db26aafeaf0da77c7de6214331e1e    False       0
# 1        99b27059f711c37de8f90ee8e4dc0d1b    False       0
# 2        cb944d94854df5afd22210bb0aa0c903    False       0
# 3        2711bac2a8cc600dae1590a6ca0edb34    False       0
# 4        b72979076d1cded25dded922195e5b1c    False       0
# ...                                   ...      ...     ...
# 7347625  bbaef6acb7e6e1a165e3b52c1ad56c67     True       5
# 7347626  cdd31f160c2db01232b9998600940d0c     True       5
# 7347627  2047dd9f2fc589340a9ec011fbcff490     True       3
# 7347628  e8df0a577d4fd440b223c54cdf641dc0     True       5
# 7347629  98c8116e2fc021e6c5a3cbb8787a993d     True       4
#
#                              date_added                    date_updated  \
# 0        Mon Aug 21 12:11:00 -0700 2017  Mon Aug 21 12:11:00 -0700 2017
# 1        Fri Feb 24 08:59:44 -0800 2017  Fri Feb 24 08:59:44 -0800 2017
# 2        Wed May 20 21:28:56 -0700 2015  Wed May 20 21:28:57 -0700 2015
# 3        Sun Jun 01 17:25:23 -0700 2014  Sun Jun 01 17:25:23 -0700 2014
# 4        Sun Sep 02 08:45:08 -0700 2012  Sun Sep 02 08:45:08 -0700 2012
# ...                                 ...                             ...
# 7347625  Thu Jun 07 08:39:53 -0700 2012  Thu Jun 07 08:39:53 -0700 2012
# 7347626  Wed Jun 06 15:17:39 -0700 2012  Wed Jun 06 15:17:39 -0700 2012
# 7347627  Mon Nov 05 10:37:35 -0800 2012  Mon Nov 05 10:37:48 -0800 2012
# 7347628  Mon Jun 04 15:45:50 -0700 2012  Mon Jun 04 15:45:50 -0700 2012
# 7347629  Sat Jun 09 11:53:18 -0700 2012  Sat Jun 09 11:53:18 -0700 2012
#
#         read_at started_at   work_id
# 0                             237194
# 1                           10202907
# 2                           19113524
# 3                            7126174
# 4                           14735455
# ...         ...        ...       ...
# 7347625                      1988464
# 7347626                      2150655
# 7347627                       296119
# 7347628                      1782551
# 7347629                      6684749
#
# [7347630 rows x 10 columns]

# %% [markdown]
# # Export to csv

# %%
interactions.to_csv('data/goodreads_interactions_comics_graphic_cleaned.csv', index=False)
